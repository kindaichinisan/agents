# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

# openai = OpenAI()

# using ollama
openai = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 123342+983452?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

# response = openai.chat.completions.create(
#     model="gpt-4.1-nano",
#     messages=messages
# )

MODEL="llama3.1"
# MODEL="mistral"
response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Here's the calculation:
#
# 123342 + 983452 = 1106894

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# What is the smallest number of spheres that can be packed into a rectangular block such that, if exactly six of them are removed from two of its three identical rectangular faces, they can be reassembled to fill up an adjacent identical rectangular hole, which has one dimension twice as large in this specific packing structure?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model=MODEL,
    # model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# ## Step 1: Understand the question description
# The question asks about the minimum number of spheres needed to pack into a rectangular block under certain conditions. These conditions involve removing exactly six spheres from two faces of the block and reassembling them to fill an adjacent hole which has one dimension twice as large.
#
# ## Step 2: Visualize the requirements
# Given that we have to remove six spheres, it must be such that these removed spheres will perfectly fit into a new space. This space is described as having one dimension twice as large than each of the six spaces created from removing spheres from two faces.
#
# ## Step 3: Determine packing efficiency and structure
# Considering optimal sphere packing (the most efficient way to pack spheres into a given container), we typically utilize hexagonal packing for spheres in 2D, and a variant of this can be extended to three dimensions by arranging spheres in a face-centered cubic lattice. However, the specific problem requires visualizing or understanding what happens when removing six spheres from two faces.
#
# ## Step 4: Relate to cubic structure
# Understanding that each removed sphere contributes to creating a space that's twice as large in one dimension suggests organizing around a basic unit of packing. This arrangement often relates to cubes and tetrahedra, given the need for a repeating pattern to fill and create spaces within the rectangular block.
#
# ## Step 5: Counting units and deducing spheres
# If we think about each removed sphere creating or needing space that can accommodate it in double one dimension, then each of these removals would effectively be part of a basic unit. Since the description points towards forming an additional equivalent space by removing six and using them as "missing" pieces to complete another set, this hints at a particular symmetry inherent in cubic structures (and their extension beyond simple cubes).
#
# ## Step 6: Determine the minimum number based on spatial patterns
# In three-dimensional space, arranging spheres or their representation as blocks involves considering how these blocks can be combined to represent individual spheres and fit together snugly, much like pieces of a jigsaw puzzle. The key insight is understanding that removing six spheres effectively allows for filling adjacent spaces under certain geometric conditions.
#
# ## Step 7: Identify optimal size combinations
# Given the problem describes specific spatial operations (e.g., fitting spheres into spaces created by their own removal), it's crucial to determine how these remove-and-fit actions directly relate to forming larger structures within a rectangular framework. This structure hints at a higher level of complexity possibly tied to multiple levels or layers of sphere packing arrangement.
#
# ## Step 8: Consider implications for spatial constraints and geometrical conditions
# The given description emphasizes that removing six spheres is essential not just for mathematical simplicity but also demonstrates an intricate relationship between how these spheres fit back into the created gaps, which suggests a higher level organization within a three-dimensional block than simple stacking or alignment arrangements.
#
# ## Step 9: Apply knowledge about geometric structures related to spheres and rectangular blocks
# Given a set of conditions specifying removals directly tied to creating space that can accommodate removed parts, applying principles of spatial relationships often leads back to examining fundamental forms such as cubes. When one dimension is doubled for adjacent spaces filled by the rearranged parts, then forming these spaces effectively might relate to configurations that inherently reflect doubling or multiplication over simple packing arrangements.
#
# ## Step 10: Identify specific number of spheres from spatial requirements and known conditions
# Upon applying knowledge about sphere packing efficiency and geometric constraints presented within the given conditions (specifically focusing on creating double-sized units by fitting original removals back in), a logical relationship points toward incorporating known pack unit combinations with their multiple configurations that effectively reflect these unique conditions laid forward.
#
# ## Step 11: Find smallest suitable package based on problem requirements
# Understanding how spheres are arranged spatially and reassembled after removal, the conditions described in the question strongly suggest an intricate configuration reflecting known forms of three-dimensional packing. Specifically fitting an extra set's structure to double-sized adjacent spaces upon a set number of original placements would logically point towards using specific combinations that yield a known or familiar geometric form when these actions complete its structure.
#
# ## Step 12: Identify smallest suitable unit or package with given problem conditions
# To fill the rectangular hole by removing exactly six spheres from two faces implies looking at how to rebuild an equivalent structure. It essentially describes an operation tied closely to understanding spatial configurations possible in three dimensions. From the previous reflections and the necessity of creating double-sized spaces through rearrangement, recognizing key forms that fit this description becomes crucial.
#
# ## Step 13: Apply knowledge about cubic packing arrangements
# The description points towards basic structural principles and how adding back into the system would create equivalent additional space based on those conditions, suggesting a configuration possible through known three-dimensional packings with higher than simple unitary efficiency.
#
#
# ## Step 14: Relate to tetrahedral or octahedral structures in understanding given problem requirements
# Given that six spheres need removal from two rectangular faces and the requirement for each of these to fill up adjacent spaces twice as large in one dimension, thinking about cubic or related packings (involving known geometric forms such as tetrahedra or octahedrons) becomes critical due to their capacity for repeated structure under specified changes. Recognizing relationships and spatial arrangements formed within conditions like this can help find the required number of initial spheres.
#
#
# ## Step 15: Determine minimum sphere count needed based on requirements and relevant geometric structures
# With the problem's specific nature in mind (focusing on a reconfigurable space after removing six spheres), deducing from basic principles related to cube-like packings or other arrangements underpinning these kinds of spatial rearrangements allows us to see how this configuration could fit as a more efficient form for packing by providing larger unit representation that the sphere removals directly influence.
#
#
# ## Step 16: Finalize minimum number based on logical progression through previous steps
# Through the combination of principles regarding optimal packing arrangements, specific operations allowing the filling of previously removed spheres into adjacent spaces and recognition of key geometric structures that can fit within described scenarios in three dimensions, it’s deduced what might constitute a basic unit in this particular problem context.
#
#
# ## Step 17: Identify mathematical pattern or configuration based on logical deductions
# Identifying relevant relationships between sphere packing efficiencies associated with reassembling given blocks points toward a more detailed geometric organization allowing removals and subsequent rebuild that fit within given space descriptions as described. Noting inherent properties of these arrangements indicates configurations could yield known, basic shapes suitable for efficient repackaging.
#
#
# ## Step 18: Draw final logical conclusion regarding smallest number required
# After carefully considering principles of spatial packing efficiency and specific actions related to reassembly operations based on problem requirements, drawing from knowledge about structures typically encountered in similar scenarios helps derive the smallest number satisfying all conditions laid out. It implies focusing on key geometric relationships inherent within three-dimensional representations like these.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# ## Step 1: Understand the question description
# The question asks about the minimum number of spheres needed to pack into a rectangular block under certain conditions. These conditions involve removing exactly six spheres from two faces of the block and reassembling them to fill an adjacent hole which has one dimension twice as large.
#
# ## Step 2: Visualize the requirements
# Given that we have to remove six spheres, it must be such that these removed spheres will perfectly fit into a new space. This space is described as having one dimension twice as large than each of the six spaces created from removing spheres from two faces.
#
# ## Step 3: Determine packing efficiency and structure
# Considering optimal sphere packing (the most efficient way to pack spheres into a given container), we typically utilize hexagonal packing for spheres in 2D, and a variant of this can be extended to three dimensions by arranging spheres in a face-centered cubic lattice. However, the specific problem requires visualizing or understanding what happens when removing six spheres from two faces.
#
# ## Step 4: Relate to cubic structure
# Understanding that each removed sphere contributes to creating a space that's twice as large in one dimension suggests organizing around a basic unit of packing. This arrangement often relates to cubes and tetrahedra, given the need for a repeating pattern to fill and create spaces within the rectangular block.
#
# ## Step 5: Counting units and deducing spheres
# If we think about each removed sphere creating or needing space that can accommodate it in double one dimension, then each of these removals would effectively be part of a basic unit. Since the description points towards forming an additional equivalent space by removing six and using them as "missing" pieces to complete another set, this hints at a particular symmetry inherent in cubic structures (and their extension beyond simple cubes).
#
# ## Step 6: Determine the minimum number based on spatial patterns
# In three-dimensional space, arranging spheres or their representation as blocks involves considering how these blocks can be combined to represent individual spheres and fit together snugly, much like pieces of a jigsaw puzzle. The key insight is understanding that removing six spheres effectively allows for filling adjacent spaces under certain geometric conditions.
#
# ## Step 7: Identify optimal size combinations
# Given the problem describes specific spatial operations (e.g., fitting spheres into spaces created by their own removal), it's crucial to determine how these remove-and-fit actions directly relate to forming larger structures within a rectangular framework. This structure hints at a higher level of complexity possibly tied to multiple levels or layers of sphere packing arrangement.
#
# ## Step 8: Consider implications for spatial constraints and geometrical conditions
# The given description emphasizes that removing six spheres is essential not just for mathematical simplicity but also demonstrates an intricate relationship between how these spheres fit back into the created gaps, which suggests a higher level organization within a three-dimensional block than simple stacking or alignment arrangements.
#
# ## Step 9: Apply knowledge about geometric structures related to spheres and rectangular blocks
# Given a set of conditions specifying removals directly tied to creating space that can accommodate removed parts, applying principles of spatial relationships often leads back to examining fundamental forms such as cubes. When one dimension is doubled for adjacent spaces filled by the rearranged parts, then forming these spaces effectively might relate to configurations that inherently reflect doubling or multiplication over simple packing arrangements.
#
# ## Step 10: Identify specific number of spheres from spatial requirements and known conditions
# Upon applying knowledge about sphere packing efficiency and geometric constraints presented within the given conditions (specifically focusing on creating double-sized units by fitting original removals back in), a logical relationship points toward incorporating known pack unit combinations with their multiple configurations that effectively reflect these unique conditions laid forward.
#
# ## Step 11: Find smallest suitable package based on problem requirements
# Understanding how spheres are arranged spatially and reassembled after removal, the conditions described in the question strongly suggest an intricate configuration reflecting known forms of three-dimensional packing. Specifically fitting an extra set's structure to double-sized adjacent spaces upon a set number of original placements would logically point towards using specific combinations that yield a known or familiar geometric form when these actions complete its structure.
#
# ## Step 12: Identify smallest suitable unit or package with given problem conditions
# To fill the rectangular hole by removing exactly six spheres from two faces implies looking at how to rebuild an equivalent structure. It essentially describes an operation tied closely to understanding spatial configurations possible in three dimensions. From the previous reflections and the necessity of creating double-sized spaces through rearrangement, recognizing key forms that fit this description becomes crucial.
#
# ## Step 13: Apply knowledge about cubic packing arrangements
# The description points towards basic structural principles and how adding back into the system would create equivalent additional space based on those conditions, suggesting a configuration possible through known three-dimensional packings with higher than simple unitary efficiency.
#
#
# ## Step 14: Relate to tetrahedral or octahedral structures in understanding given problem requirements
# Given that six spheres need removal from two rectangular faces and the requirement for each of these to fill up adjacent spaces twice as large in one dimension, thinking about cubic or related packings (involving known geometric forms such as tetrahedra or octahedrons) becomes critical due to their capacity for repeated structure under specified changes. Recognizing relationships and spatial arrangements formed within conditions like this can help find the required number of initial spheres.
#
#
# ## Step 15: Determine minimum sphere count needed based on requirements and relevant geometric structures
# With the problem's specific nature in mind (focusing on a reconfigurable space after removing six spheres), deducing from basic principles related to cube-like packings or other arrangements underpinning these kinds of spatial rearrangements allows us to see how this configuration could fit as a more efficient form for packing by providing larger unit representation that the sphere removals directly influence.
#
#
# ## Step 16: Finalize minimum number based on logical progression through previous steps
# Through the combination of principles regarding optimal packing arrangements, specific operations allowing the filling of previously removed spheres into adjacent spaces and recognition of key geometric structures that can fit within described scenarios in three dimensions, it’s deduced what might constitute a basic unit in this particular problem context.
#
#
# ## Step 17: Identify mathematical pattern or configuration based on logical deductions
# Identifying relevant relationships between sphere packing efficiencies associated with reassembling given blocks points toward a more detailed geometric organization allowing removals and subsequent rebuild that fit within given space descriptions as described. Noting inherent properties of these arrangements indicates configurations could yield known, basic shapes suitable for efficient repackaging.
#
#
# ## Step 18: Draw final logical conclusion regarding smallest number required
# After carefully considering principles of spatial packing efficiency and specific actions related to reassembly operations based on problem requirements, drawing from knowledge about structures typically encountered in similar scenarios helps derive the smallest number satisfying all conditions laid out. It implies focusing on key geometric relationships inherent within three-dimensional representations like these.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "How to start the business idea of providing book cutting service at a cost in Carousel?"}]

# Then make the first call:

response = openai.chat.completions.create(
    model=MODEL,
    # model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message
display(Markdown(business_idea))
# Out:
#  Starting a bookbinding or book-cutting service in Carousel involves several steps. Here's a simplified guide to help you get started:
#
# 1. **Research**: Understand the market, your potential customers, and the competition. Look into trends in book art, the demand for handcrafted books, and existing bookbinding businesses in Carousel.
#
# 2. **Business Plan**: Develop a business plan that outlines your mission, target audience, marketing strategies, pricing structure, and financial projections. This will serve as a roadmap for your business.
#
# 3. **Skills Development**: Ensure you have the necessary skills or plan to learn them. These might include traditional bookbinding techniques, modern binding methods, design principles, and possibly digital tools for marketing and administration.
#
# 4. **Supplies Sourcing**: Identify suppliers for materials like books, leather, cloth, and tools. You may need to test different vendors for quality and cost.
#
# 5. **Workspace Setup**: Find a suitable workspace that meets your needs in terms of size, equipment, and location. Ensure it is zoned for this type of business activity.
#
# 6. **Legal Requirements**: Register your business with the appropriate authorities, obtain necessary licenses or permits, and set up any tax accounts. You may also need liability insurance.
#
# 7. **Branding & Marketing**: Create a unique brand identity for your business, including a name, logo, website, and social media presence. Implement marketing strategies to reach potential customers, such as networking with local artists and writers, attending craft fairs, and using online platforms.
#
# 8. **Launch**: Once everything is in place, launch your business. Start taking orders from clients, fulfilling them with your custom book-cutting services, and continuously striving to improve the quality of your work and customer satisfaction.
